# %%
import tweepy

# %%
consumer_key = 'XXXXXXXXXXXXXXXXXXXXXXXX'
consumer_secret = 'XXXXXXXXXXXXXXXXXXXXXXXXX'
access_token = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'
access_token_secret = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
api

# %%
#20 elemenst having hashtag covid
search_results = api.search(q='covid', count=20)
search_results
# Out:
# [Status(_api=<tweepy.api.API object at 0x000002409F946DA0>, _json={'created_at': 'Fri Jun 19 14:20:14 +0000 2020', 'id': 1273983938030116868, 'id_str': '1273983938030116868', 'text': 'RT @wewantMor_: did teachers &amp; nurses get a bonus as thanks to their hard work during COVID?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'wewantMor_', 'name': 'MNP', 'id': 50225321, 'id_str': '50225321', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2729365664, 'id_str': '2729365664', 'name': 'Trululu', 'screen_name': 'fak3deeep', 'location': 'Αττική, Ελλάς ', 'description': "I'm not 14\n\nIg:fakedeeep", 'url': 'https://t
# ...

# %%
#checking how these elements are actually one by one
for item in search_results:
    print(item._json)    #data parse--> python..json is basically a standard -> exchanging data from one prog lang to other(identify key value type relationship)
    break
# Out:
# {'created_at': 'Fri Jun 19 14:20:14 +0000 2020', 'id': 1273983938030116868, 'id_str': '1273983938030116868', 'text': 'RT @wewantMor_: did teachers &amp; nurses get a bonus as thanks to their hard work during COVID?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'wewantMor_', 'name': 'MNP', 'id': 50225321, 'id_str': '50225321', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2729365664, 'id_str': '2729365664', 'name': 'Trululu', 'screen_name': 'fak3deeep', 'location': 'Αττική, Ελλάς ', 'description': "I'm not 14\n\nIg:fakedeeep", 'url': 'https://t.co/PdxjC3WktO', 'entities': {'url': {'urls': [{'url': 'https://t.
# ...

# %%
one_tweet=search_results[0]._json

# %%
#using key--> getting all keys
one_tweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'is_quote_status', 'quoted_status_id', 'quoted_status_id_str', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
#getting enties present in above dictionary of one_tweet.keys


one_tweet_entities=one_tweet['entities']
one_tweet_entities
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'user_mentions': [{'screen_name': 'wewantMor_',
#    'name': 'MNP',
#    'id': 50225321,
#    'id_str': '50225321',
#    'indices': [3, 14]}],
#  'urls': []}

# %%
#along with covid in that tweet there are some hashtags also present(we're looking for these hashtags now)
result=[]
for item in search_results:
    result.append(item._json)
    
print(result)
# Out:
# [{'created_at': 'Fri Jun 19 14:20:14 +0000 2020', 'id': 1273983938030116868, 'id_str': '1273983938030116868', 'text': 'RT @wewantMor_: did teachers &amp; nurses get a bonus as thanks to their hard work during COVID?', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'wewantMor_', 'name': 'MNP', 'id': 50225321, 'id_str': '50225321', 'indices': [3, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2729365664, 'id_str': '2729365664', 'name': 'Trululu', 'screen_name': 'fak3deeep', 'location': 'Αττική, Ελλάς ', 'description': "I'm not 14\n\nIg:fakedeeep", 'url': 'https://t.co/PdxjC3WktO', 'entities': {'url': {'urls': [{'url': 'https://t
# ...

# %%
#load a text file
all_hashtags=[]
for item in search_results:
    print(all_hashtags.append(item._json['entities']['hashtags']))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
for tweet in search_results:
    data = tweet._json
    print(data['user']['followers_count'])
# Out:
# 830
# 177
# 62
# 114
# 551
# 279
# 396
# 255
# 2772
# 687
# 530
# 279
# 531
# 14
# 0
# 3017
# 12
# 5445
# 2410
# 3

# %%
one_tweet['user']
# Out:
# {'id': 2729365664,
#  'id_str': '2729365664',
#  'name': 'Trululu',
#  'screen_name': 'fak3deeep',
#  'location': 'Αττική, Ελλάς ',
#  'description': "I'm not 14\n\nIg:fakedeeep",
#  'url': 'https://t.co/PdxjC3WktO',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/PdxjC3WktO',
#      'expanded_url': 'https://www.tumblr.com/blog/fake-deeep',
#      'display_url': 'tumblr.com/blog/fake-deeep',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 830,
#  'friends_count': 131,
#  'listed_count': 0,
#  'created_at': 'Wed Aug 13 12:44:58 +0000 2014',
#  'favourites_count': 6413,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 6458,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': False,
#  'profile_background_color': '000000',
# ...

# %%
user_data = api.get_user(id='2729365664')
user_data = user_data._json
user_data.keys()
# Out:
# dict_keys(['id', 'id_str', 'name', 'screen_name', 'location', 'profile_location', 'description', 'url', 'entities', 'protected', 'followers_count', 'friends_count', 'listed_count', 'created_at', 'favourites_count', 'utc_offset', 'time_zone', 'geo_enabled', 'verified', 'statuses_count', 'lang', 'status', 'contributors_enabled', 'is_translator', 'is_translation_enabled', 'profile_background_color', 'profile_background_image_url', 'profile_background_image_url_https', 'profile_background_tile', 'profile_image_url', 'profile_image_url_https', 'profile_banner_url', 'profile_link_color', 'profile_sidebar_border_color', 'profile_sidebar_fill_color', 'profile_text_color', 'profile_use_background_image', 'has_extended_profile', 'default_profile', 'default_profile_image', 'following', 'follow_request_sent', 'notifications', 'translator_type'])

# %%
#function to find user with max followers
"""
    input : hashtag
    output : information of the user with maximum no followers. 
"""

def get_user_with_max_followers(hashtag):

    search_results = api.search(q=hashtag, count=20)
    all_followers = []
    tweets = []
    
    for tweet in search_results:
        data = tweet._json
        followers = data['user']['followers_count']
        all_followers.append(followers)
        tweets.append(data)

    max_no_followers = max(all_followers)
    
    target_person_index = all_followers.index(max_no_followers)
    person_info = tweets[target_person_index]
    user_id = person_info['user']['id_str']

    return api.get_user(id=user_id)._json

# %%
get_user_with_max_followers('covid')
# Out:
# {'id': 20177010,
#  'id_str': '20177010',
#  'name': 'KCCI News',
#  'screen_name': 'KCCINews',
#  'location': 'Des Moines, Iowa',
#  'profile_location': None,
#  'description': 'KCCI 8 News is the most-watched station in Central Iowa and the leader in local news coverage.',
#  'url': 'http://t.co/nwicNvY3w5',
#  'entities': {'url': {'urls': [{'url': 'http://t.co/nwicNvY3w5',
#      'expanded_url': 'http://www.kcci.com/index.html',
#      'display_url': 'kcci.com/index.html',
#      'indices': [0, 22]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 121611,
#  'friends_count': 859,
#  'listed_count': 996,
#  'created_at': 'Thu Feb 05 19:22:44 +0000 2009',
#  'favourites_count': 1356,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'verified': True,
#  'statuses_count': 293929,
#  'lang': None,
#  'status': {'created_at': 'Fri Jun 19 15:10:07 +0000 2020',
#   'id': 1273996489744883714,
#   'id_str': '1273996489744883714',
# ...
